# %% [markdown]
# <a href="https://colab.research.google.com/github/Ujwalvelpula/ai-mental-health-chatbot/blob/main/AI_bot_for_streesed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# !pip install transformers
# !pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 63.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 90.1 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
from transformers import pipeline

# Load sentiment analysis model
sentiment_analyzer = pipeline("sentiment-analysis")

# Predefined responses
responses = {
    "happy": "I'm glad to hear that! 🌸 Keep spreading positivity!",
    "sad": "I'm sorry you feel sad. 💙 Try writing down your thoughts in a journal, it may help.",
    "anxious": "When anxiety hits, try the 4-7-8 breathing technique: inhale 4s, hold 7s, exhale 8s. 🌬️",
    "stressed": "Stress can be tough 😞. A short walk or some music might help calm your mind."
}

# Streamlit UI
st.title("🌿 AI Chatbot for Stress & Mental Health")
st
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# 2025-09-17 09:45:47.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-17 09:45:47.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-17 09:45:47.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# <module 'streamlit' from '/usr/local/lib/python3.12/dist-packages/streamlit/__init__.py'>

# %%
# !pip install streamlit
# !pip install transformers
# !pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 48.3 MB/s eta 0:00:00
# ...

# %%
# !pip install streamlit
# !pip install transformers
# !pip install torch
import streamlit as st
from transformers import pipeline

# Load sentiment analysis model
sentiment_analyzer = pipeline("sentiment-analysis")

# Predefined responses
responses = {
    "happy": "I'm glad to hear that! 🌸 Keep spreading positivity!",
    "sad": "I'm sorry you feel sad. 💙 Try writing down your thoughts in a journal, it may help.",
    "anxious": "When anxiety hits, try the 4-7-8 breathing technique: inhale 4s, hold 7s, exhale 8s. 🌬️",
    "stressed": "Stress can be tough 😞. A short walk or some music might help calm your mind."
}

# Streamlit UI
st.title("🌿 AI Chatbot for Stress & Mental Health")
st
